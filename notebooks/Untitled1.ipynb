# %%
# Cell 0 — Mount Drive first
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# Cell 1 — Configure git identity
# !git config --global user.email "willsutherland@acadiau.ca"
# !git config --global user.name "willsuther"

# %%
# Cell 2 — Confirm .gitignore is in place
# !cat /content/drive/MyDrive/running_coach/.gitignore
# Out:
# # Credentials
# .env
#
# # Virtual environment
# .venv/
#
# # Garmin database and workout data — too large and contains personal data
# data/
#
# # ChromaDB vector store — regenerated by Phase 3 notebook
# memory/chroma/
#
# # Python cache
# __pycache__/
# *.pyc
# *.pyo
#
# # Jupyter checkpoints
# .ipynb_checkpoints/
#
# # OS files
# .DS_Store
# Thumbs.db

# %%
# Cell 3 — Commit and push
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')

# !cd /content/drive/MyDrive/running_coach && git commit -m "Add coordinator agent, demo notebook, updated tools"
# !cd /content/drive/MyDrive/running_coach && git remote set-url origin https://{token}@github.com/willsuther/running-coach-agent-swarm.git
# !cd /content/drive/MyDrive/running_coach && git push origin main

# %%
# Cell 3 — Initialize repo and check what would be committed
# !cd /content/drive/MyDrive/running_coach && git init
# !cd /content/drive/MyDrive/running_coach && git status --short
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/running_coach/.git/
# ?? .gitignore
# ?? agents/
# ?? config.py
# ?? notebooks/
# ?? tools/
# ?? ui/

# %%
# Cell 4 — Stage and commit
# !cd /content/drive/MyDrive/running_coach && git add .
# !cd /content/drive/MyDrive/running_coach && git commit -m "Initial commit — Running Coach Agent Swarm"
# Out:
# [master (root-commit) c346b88] Initial commit — Running Coach Agent Swarm
#  17 files changed, 4811 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 agents/feedback_agent.py
#  create mode 100644 agents/planner_agent.py
#  create mode 100644 agents/recovery_agent.py
#  create mode 100644 config.py
#  create mode 100644 notebooks/01_phase1_environment_setup_garminDB.ipynb
#  create mode 100644 notebooks/02_phase2_test_tools.ipynb
#  create mode 100644 notebooks/03_phase3_chromadb_memory.ipynb
#  create mode 100644 notebooks/04_agents.ipynb
#  create mode 100644 notebooks/Untitled0.ipynb
#  create mode 100644 notebooks/Untitled1.ipynb
#  create mode 100644 tools/calculate_pace_zones.py
#  create mode 100644 tools/calculate_training_load.py
#  create mode 100644 tools/memory_retrieval.py
#  create mode 100644 tools/parse_workout_data.py
#  create mode 100644 tools/query_garmin_db.py
#  create mode 100644 ui/coach_ui.py

# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')

# !cd /content/drive/MyDrive/running_coach && \
  git remote set-url origin https://{token}@github.com/willsuther/running-coach-agent-swarm.git && \
  git branch -M main && \
  git push -u origin main
# Out:
# Enumerating objects: 23, done.
# Counting objects: 100% (23/23), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (22/22), done.
# Writing objects: 100% (23/23), 105.59 KiB | 1001.00 KiB/s, done.
# Total 23 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/willsuther/running-coach-agent-swarm.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !cd /content/drive/MyDrive/running_coach && git add README.md
# !cd /content/drive/MyDrive/running_coach && git commit -m "Update README — add Coordinator Agent design"

from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
# !cd /content/drive/MyDrive/running_coach && git push origin main
# Out:
# [main 3907978] Update README — add Coordinator Agent design
#  1 file changed, 308 insertions(+)
#  create mode 100644 README.md
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 5.42 KiB | 173.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/willsuther/running-coach-agent-swarm.git
#    c346b88..3907978  main -> main
